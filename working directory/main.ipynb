# %%
import random 
from copy import deepcopy
import time

graphSSA = {}
graphLV = {}
linkerSSA = {}
linkerLV = {}
tempLV={}
totalLengthAllLV=0
tempFitnessScore = []
genomeCounter =0
BestLIST=[]

def createGraphSSA(vertex) : 
    
    for each in range(vertex):
       graphSSA[each] = []

    for i in range(vertex):
        if(i == 0):
            addEdge(i,i+1)
            addEdge(i,i+2)
            
        elif(i==V-1):
            pass
        elif(i== vertex-1 or i== vertex-2):
            addEdge(i,i+1)
        else:
            addEdge(i,i+2)

def createGraphLVMOD(vertex):   
    for each in range(vertex):
        graphLV[each] = []
        
    for i in range(int(vertex/2)):
        src = random.randrange(0,vertex-1)
        dst = random.choice(linkerSSA[src])
        while(len(graphLV[src])>0 or src==dst):
            src = random.randrange(0,vertex-1)
 
            dst = random.choice(linkerSSA[src])
        

        graphLV[src].append(dst)


def setConnection(num,Graph,linkerGraph):      
    for each in range(num):
        visited =[]
        linkerGraph[each] = checkConnection(visited,Graph,each)
        linkerGraph[each].pop(0)


def checkConnection(visited,graph,node):   
    if node not in visited:
        visited.append(node)
        for next in graph[node]:
            checkConnection(visited, graph, next)
    return visited


def addEdge(src,dst):
    {
        graphSSA[src].append(dst)

    }
     


V = random.randrange(10,20)
createGraphSSA(V)
setConnection(V,graphSSA,linkerSSA)
createGraphLVMOD(V)
setConnection(V,graphLV,linkerLV)
print("SSA Graph: ",graphSSA)
print("LV Graph: ",graphLV)
#print("LinkerSSA",linkerSSA)
#print("LinkerLV",linkerLV)
tempLV=deepcopy(graphLV)
# Out:
# SSA Graph:  {0: [1, 2], 1: [3], 2: [4], 3: [5], 4: [6], 5: [7], 6: [8], 7: [9], 8: [10], 9: [11], 10: [12], 11: [13], 12: [14], 13: [15], 14: [16], 15: [16], 16: []}
# LV Graph:  {0: [5], 1: [], 2: [], 3: [13], 4: [16], 5: [7], 6: [8], 7: [13], 8: [], 9: [], 10: [12], 11: [], 12: [16], 13: [], 14: [], 15: [], 16: []}

# %%
def splitLVtemp(src,dst,point):
    
    if( (dst in tempLV[src]) and (point in linkerSSA[src]) and  point<dst):
        if(point not in tempLV[src] and point in lengthLV(graphSSA,src,graphLV[src][0])):
            tempLV[src].append(point)
            tempLV[src].sort()
            print("inside split",src,dst,point)
    


print(graphLV)
# Out:
# {0: [], 1: [], 2: [8], 3: [5], 4: [11], 5: [], 6: [11], 7: [9], 8: [], 9: [11], 10: [], 11: []}

# %%
#still working on these functions, Not tested yet.
def coalesceLVtemp(src1,dst1,src2,dst2):
    if(dst1==src2 and (dst2 in linkerSSA[src1]) and (len(temp[src1]>1) and dst2 in linkerSSA[dst1] )):
        tempLV[src].remove(dst1)
        if(dst2 not in tempLV[src]):
            tempLV[src].append(dst1)
        tempLV[src].sort()    

def randomCoalesceGenerator(total,vertex):
    gene = []
    for each in range(total):
        src1 = random.randrange(0,vertex-1)
        dst1 = random.randrange(0,vertex-1)
        src2 = random.randrange(0,vertex-1)
        dst2 = random.randrange(0,vertex-1)

        temp= [src1,dst1,src2,dst2]
        gene.append(temp)
    return gene

def genomeExecuteCoalesce(genome):
    for each in range(len(genome)):
        s1 = genome[each][0]
        d1 = genome[each][1]
        s2 = genome[each][2]
        d2 = genome[each][3]
        coalesceLVtemp(s1,d1,s2,d2)

print(graphLV)
# Out:
# {0: [], 1: [], 2: [8], 3: [5], 4: [11], 5: [], 6: [11], 7: [9], 8: [], 9: [11], 10: [], 11: []}

# %%
def lengthLV(graph, start, end, path=[]):

    path = path + [start]
    if start == end:
        return path
    if start not in graph:
        return None
    length = None
    for node in graph[start]:
        if node not in path:
            newpath = lengthLV(graph, node, end, path)
            if newpath:
                if not length or len(newpath) < len(length):
                    length = newpath
    return length


def lengthTotalLV():
    total= 0
    for each in range(0,len(graphLV)):
        if not graphLV[each]:
            pass
        else:
            total += len(lengthLV(graphSSA,each,graphLV[each][0]))-1

    
    return total
            
totalLengthAllLV = lengthTotalLV()
print(totalLengthAllLV) 
print(graphLV)

def fitnessScore(graphMeasure):
    totalNumberLV = 0

    for each in graphMeasure:
        totalNumberLV+= len(graphMeasure[each])


    ft = totalNumberLV/totalLengthAllLV
  
    return ft


print(graphLV)
# Out:
# 13
# {0: [], 1: [], 2: [8], 3: [5], 4: [11], 5: [], 6: [11], 7: [9], 8: [], 9: [11], 10: [], 11: []}
# {0: [], 1: [], 2: [8], 3: [5], 4: [11], 5: [], 6: [11], 7: [9], 8: [], 9: [11], 10: [], 11: []}

# %%
"""baseSplitNumber = 50
nextGenesNumber = 10
newSplitNumber = 5"""

def randomSplitGenerator(total,vertex):
    gene = []
    for each in range(total):
        start = random.randrange(0,vertex-1)
        end = random.randrange(0,vertex-1)
        point = random.randrange(0,vertex-1)
        temp= [start,end,point]
        gene.append(temp)
    return gene

def genomeExecute(genome):
    for each in range(len(genome)):
        s = genome[each][0]
        e = genome[each][1]
        p = genome[each][2]
        splitLVtemp(s,e,p)

# %%
baseSplitFunctionNumber = 20
baseGenomeSize = 20
incrementGene=10


genomeList=[]

def geneticAlgorithm():
   
    for each in range(baseGenomeSize):
        genomeList.append([])
        
    
    for each in range(baseGenomeSize):
        temp = randomSplitGenerator(baseSplitFunctionNumber,V)
        #print(temp,"\n")
        genomeList[each].append(temp)

    for each in genomeList: 
        for i in each:
            genomeExecute(i)
    



def GA():

    global tempLV
    print("GraphLV",graphLV)
    print("tempLV",tempLV)

    for each in range(baseGenomeSize):
        genomeList.append([])

    for each in range(baseGenomeSize):
        temp = randomSplitGenerator(baseSplitFunctionNumber,V)
        #print(temp,"\n")
        genomeList[each].append(temp)

    for each in genomeList: # execute the genomes
        for i in each:
            genomeExecute(i)
            
        tempFitnessScore.append(fitnessScore(tempLV))
        tempLV=deepcopy(graphLV)
    
    global genomeCounter
    genomeCounter +=1
    print("Genome Counter: ", genomeCounter)

# %%
def crossOverNMutate(listCrossOver):
    crossed=[]
    for each in range(0,(int(len(listCrossOver)/2))):


        first=random.choice(listCrossOver[0])
        second=random.choice(listCrossOver[0])
        point=random.randrange(1,baseGenomeSize-1)

        new=[first[:point]+second[point:]]
        
        start = random.randrange(0,V-1)
        end = random.randrange(0,V-1)
        point = random.randrange(0,V-1)
        temp= [start,end,point]
        
        new[0][0]=temp
        crossed.append(new)
    return crossed

# %%
GA()
while(1 not in tempFitnessScore):
    bestSplitFunctions=[]
    newTempFitnessScore=[]
    for each in range(0,int(len(tempFitnessScore)/2)):
        tempMax =max(tempFitnessScore)
        index=tempFitnessScore.index(tempMax)
        bestSplitFunctions.append(genomeList[index])
        newTempFitnessScore.append(tempMax)
        tempFitnessScore.remove(tempMax)

    tempFitnessScore=newTempFitnessScore #Doubt
    genomeList=bestSplitFunctions
    
    genomeList=crossOverNMutate(bestSplitFunctions)

    
    listLengthPreviousGenomeList=len(genomeList)
    for each in range(len(genomeList),incrementGene+len(genomeList)):
        genomeList.append([])

    for each in range(listLengthPreviousGenomeList,incrementGene+listLengthPreviousGenomeList):
        temp = randomSplitGenerator(baseSplitFunctionNumber,V)
        genomeList[each].append(temp)
    tempFitnessScore=[]
    for each in genomeList:

        for i in each:
            
            genomeExecute(i)
        tempFitnessScore.append(fitnessScore(tempLV))
        
    tempLV=deepcopy(graphLV)

    
    if(genomeCounter==500):
        break
    
    genomeCounter +=1
    print("genome Counter \n",genomeCounter)
    
    BestLIST=genomeList

    
    if(genomeCounter%10==0):
        incrementGene +=5
    
    if(genomeCounter%100==0):
        time.sleep(5)


    print("This is max FT: \n",max(tempFitnessScore))
# Out:
# GraphLV {0: [], 1: [], 2: [8], 3: [5], 4: [11], 5: [], 6: [11], 7: [9], 8: [], 9: [11], 10: [], 11: []}
# tempLV {0: [], 1: [], 2: [8], 3: [5], 4: [11], 5: [], 6: [11], 7: [9], 8: [], 9: [11], 10: [], 11: []}
# Genome Counter:  1
# genome Counter
#  2
# This is max FT:
#  0.46153846153846156
# genome Counter
#  3
# This is max FT:
#  0.46153846153846156
# genome Counter
#  4
# This is max FT:
#  0.46153846153846156
# genome Counter
#  5
# This is max FT:
#  0.46153846153846156
# inside split 2 8 6
# genome Counter
#  6
# This is max FT:
#  0.5384615384615384
# inside split 2 8 6
# genome Counter
#  7
# This is max FT:
#  0.5384615384615384
# inside split 2 8 6
# inside split 2 6 4
# genome Counter
#  8
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# genome Counter
#  9
# This is max FT:
#  0.5384615384615384
# inside split 2 8 6
# genome Counter
#  10
# This is max FT:
#  0.5384615384615384
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  11
# This is max FT:
#  0.6153846153846154
# inside split 2 8 4
# genome Counter
#  12
# This is max FT:
#  0.5384615384615384
# inside split 2 8 4
# genome Counter
#  13
# This is max FT:
#  0.5384615384615384
# inside split 2 8 4
# genome Counter
#  14
# This is max FT:
#  0.5384615384615384
# inside split 2 8 4
# inside split 2 8 6
# genome Counter
#  15
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  16
# This is max FT:
#  0.6153846153846154
# inside split 2 8 4
# genome Counter
#  17
# This is max FT:
#  0.5384615384615384
# inside split 2 8 4
# genome Counter
#  18
# This is max FT:
#  0.5384615384615384
# inside split 2 8 4
# genome Counter
#  19
# This is max FT:
#  0.5384615384615384
# inside split 2 8 4
# genome Counter
#  20
# This is max FT:
#  0.5384615384615384
# inside split 2 8 4
# genome Counter
#  21
# This is max FT:
#  0.5384615384615384
# inside split 2 8 4
# genome Counter
#  22
# This is max FT:
#  0.5384615384615384
# inside split 2 8 4
# inside split 2 8 6
# genome Counter
#  23
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 6 4
# genome Counter
#  24
# This is max FT:
#  0.6153846153846154
# inside split 2 8 4
# genome Counter
#  25
# This is max FT:
#  0.5384615384615384
# inside split 2 8 4
# genome Counter
#  26
# This is max FT:
#  0.5384615384615384
# inside split 2 8 4
# genome Counter
#  27
# This is max FT:
#  0.5384615384615384
# inside split 2 8 4
# genome Counter
#  28
# This is max FT:
#  0.5384615384615384
# inside split 2 8 4
# inside split 2 8 6
# genome Counter
#  29
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  30
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  31
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  32
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  33
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  34
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  35
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  36
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  37
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  38
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  39
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  40
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  41
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  42
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  43
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  44
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  45
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  46
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  47
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  48
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  49
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  50
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  51
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  52
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  53
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  54
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  55
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  56
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  57
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  58
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  59
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  60
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  61
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  62
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  63
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  64
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  65
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  66
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  67
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  68
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  69
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  70
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  71
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  72
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  73
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  74
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  75
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  76
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  77
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  78
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  79
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  80
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  81
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  82
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  83
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  84
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  85
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  86
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  87
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  88
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  89
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  90
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  91
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  92
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  93
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  94
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  95
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  96
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  97
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  98
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  99
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  100
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  101
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  102
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  103
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  104
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  105
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  106
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  107
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  108
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  109
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  110
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  111
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  112
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  113
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  114
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  115
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  116
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  117
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  118
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  119
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  120
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  121
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  122
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  123
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  124
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  125
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  126
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  127
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  128
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  129
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  130
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  131
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  132
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  133
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  134
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  135
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  136
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  137
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  138
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  139
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  140
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  141
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  142
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  143
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  144
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  145
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  146
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  147
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  148
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  149
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  150
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  151
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  152
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  153
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  154
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  155
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  156
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  157
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  158
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  159
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  160
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  161
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  162
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  163
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  164
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  165
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  166
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  167
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  168
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  169
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  170
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  171
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  172
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  173
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  174
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  175
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  176
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  177
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  178
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  179
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  180
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  181
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  182
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  183
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  184
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  185
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  186
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  187
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  188
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  189
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  190
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  191
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  192
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  193
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  194
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  195
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  196
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  197
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  198
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  199
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  200
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  201
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  202
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  203
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  204
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  205
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  206
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  207
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  208
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  209
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  210
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  211
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  212
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  213
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  214
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  215
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  216
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  217
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  218
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  219
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  220
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  221
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  222
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  223
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  224
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  225
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  226
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  227
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  228
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  229
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  230
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  231
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  232
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  233
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  234
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  235
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  236
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  237
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  238
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  239
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  240
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  241
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  242
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  243
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  244
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  245
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  246
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  247
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  248
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  249
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  250
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  251
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  252
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  253
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  254
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  255
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  256
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  257
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  258
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  259
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  260
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  261
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  262
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  263
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  264
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  265
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  266
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  267
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  268
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  269
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  270
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  271
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  272
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  273
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  274
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  275
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  276
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  277
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  278
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  279
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  280
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  281
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  282
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  283
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  284
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  285
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  286
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  287
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  288
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  289
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  290
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  291
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  292
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  293
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  294
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  295
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  296
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  297
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  298
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  299
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  300
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  301
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  302
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  303
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  304
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  305
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  306
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  307
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  308
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  309
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  310
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  311
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  312
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  313
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  314
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  315
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  316
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  317
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  318
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  319
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  320
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  321
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  322
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  323
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  324
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  325
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  326
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  327
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  328
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  329
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  330
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  331
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  332
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  333
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  334
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  335
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  336
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  337
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  338
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  339
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  340
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  341
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  342
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  343
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  344
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  345
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  346
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  347
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  348
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  349
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  350
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  351
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  352
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  353
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  354
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  355
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  356
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  357
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  358
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  359
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  360
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  361
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  362
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  363
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  364
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  365
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  366
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  367
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  368
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  369
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  370
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  371
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  372
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  373
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  374
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  375
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  376
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  377
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  378
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  379
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  380
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  381
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  382
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  383
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  384
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  385
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  386
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  387
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  388
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  389
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  390
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  391
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  392
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  393
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  394
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  395
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  396
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  397
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  398
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  399
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  400
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  401
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  402
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  403
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  404
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  405
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  406
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  407
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  408
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  409
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  410
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  411
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  412
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  413
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  414
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  415
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  416
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  417
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  418
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  419
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  420
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  421
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  422
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  423
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  424
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  425
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  426
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  427
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  428
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  429
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  430
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  431
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  432
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  433
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  434
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  435
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  436
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  437
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  438
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  439
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  440
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  441
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  442
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  443
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  444
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  445
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  446
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  447
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  448
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  449
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  450
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  451
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  452
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  453
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  454
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  455
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  456
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  457
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  458
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  459
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  460
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  461
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  462
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  463
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  464
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  465
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  466
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  467
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  468
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  469
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  470
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  471
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  472
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  473
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  474
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  475
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  476
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  477
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  478
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  479
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  480
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  481
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  482
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  483
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  484
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  485
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  486
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  487
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  488
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  489
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  490
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  491
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  492
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  493
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  494
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  495
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  496
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  497
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  498
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  499
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4
# genome Counter
#  500
# This is max FT:
#  0.6153846153846154
# inside split 2 8 6
# inside split 2 8 4

# %%
for each in BestLIST: 

    for i in each:
        
        genomeExecute(i)
    tempFitnessScore.append(fitnessScore(tempLV))
print(tempLV)
print(graphSSA)
# Out:
# inside split 2 8 6
# inside split 2 8 4
# {0: [], 1: [], 2: [4, 6, 8], 3: [5], 4: [11], 5: [], 6: [11], 7: [9], 8: [], 9: [11], 10: [], 11: []}
# {0: [1, 2], 1: [3], 2: [4], 3: [5], 4: [6], 5: [7], 6: [8], 7: [9], 8: [10], 9: [11], 10: [11], 11: []}
